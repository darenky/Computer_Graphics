# %% [markdown]
# # LAB6.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# "Водяний знак вбудовувати у канал Blue" означає, що біти водяного знаку (або текстової інформації) будуть вбудовуватися в біти синього кольорового каналу (Blue) пікселів зображення.
#
# Steganography is the Least Significant Bit. The Least Significant Bit (LSB) method hides the message by inserting the message at the lower or rightmost bits in the cover work file as a medium to hide the message.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# LSB Steganography is an image steganography technique in which messages are hidden inside an image by replacing each pixel’s least significant bit with the bits of the message to be hidden.

# %%
def Encode(src, message, dest):

    img = Image.open(src, 'r')
    width, height = img.size
    array = np.array(list(img.getdata()))

    if img.mode == 'RGB':
        n = 3
    elif img.mode == 'RGBA':
        n = 4
    total_pixels = array.size//n
